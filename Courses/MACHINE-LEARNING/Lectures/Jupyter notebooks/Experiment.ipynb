# %% [markdown]
# ### What happen when all data points are belong to one label?

# %%
#put here your ``numero di matricola''
numero_di_matricola = 2106235

from sklearn import datasets, preprocessing, linear_model, svm
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.array([[ -2.1, 1.7], [ 0.9, 1], [-0.2, 1.3], [0.5, 2.1]])
y = np.array([1, 1, 1, 1])

# scaler = preprocessing.StandardScaler()
# scaler.fit(X)
# X = scaler.transform(X)

# %%
#Creating a SVM model
# TO DO: COMPLETE
model_svm = svm.SVC(kernel="linear", C=100000000)

#Training the model
# TO DO: COMPLETE
model_svm.fit(X,y)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm.score(X,y)

#Print the training error
# TO DO: COMPLETE
print("training error: ", training_error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 7
#       3 model_svm = svm.SVC(kernel="linear", C=100000000)
#       5 #Training the model
#       6 # TO DO: COMPLETE
# ----> 7 model_svm.fit(X,y)
#       9 #Get the training error as 1 - score()
#      10 # TO DO: COMPLETE
#      11 training_error = 1 - model_svm.score(X,y)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/sklearn/svm/_base.py:199, in BaseLibSVM.fit(self, X, y, sample_weight)
#     189 else:
#     190     X, y = self._validate_data(
#     191         X,
#     192         y,
#    (...)
#     196         accept_large_sparse=False,
#     197     )
# --> 199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#     204 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/sklearn/svm/_base.py:747, in BaseSVC._validate_targets(self, y)
#     745 self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#     746 if len(cls) < 2:
# --> 747     raise ValueError(
#     748         "The number of classes has to be greater than one; got %d class"
#     749         % len(cls)
#     750     )
#     752 self.classes_ = cls
#     754 return np.asarray(y, dtype=np.float64, order="C")
#
# ValueError: The number of classes has to be greater than one; got 1 class

# %%
# TO DO: WRITE THE CODE TO PLOT THE DECISION BOUNDARY
plt.scatter(X[:, 0], X[:, 1], c=y, s=30)
ax = plt.gca()
plt.title("Plot of SVM decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z = model_svm.decision_function(xy).reshape(XX.shape)#COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 15
#      11 xy = np.vstack([XX.ravel(), YY.ravel()]).T
#      12 # use the decision_function call to obtain the boundary to be plot.
#      13 # TO DO
# ---> 15 Z = model_svm.decision_function(xy).reshape(XX.shape)#COMPLETE
#      17 # plot decision boundary and margins
#      18 ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
#      19 linestyles=['-'])
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/sklearn/svm/_base.py:783, in BaseSVC.decision_function(self, X)
#     756 def decision_function(self, X):
#     757     """Evaluate the decision function for the samples in X.
#     758
#     759     Parameters
#    (...)
#     781     transformation of ovo decision function.
#     782     """
# --> 783     dec = self._decision_function(X)
#     784     if self.decision_function_shape == "ovr" and len(self.classes_) > 2:
#     785         return _ovr_decision_function(dec < 0, -dec, len(self.classes_))
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/sklearn/svm/_base.py:532, in BaseLibSVM._decision_function(self, X)
#     518 """Evaluates the decision function for the samples in X.
#     519
#     520 Parameters
#    (...)
#     528     in the model.
#     529 """
#     530 # NOTE: _validate_for_predict contains check for is_fitted
#     531 # hence must be placed before any other attributes are used.
# --> 532 X = self._validate_for_predict(X)
#     533 X = self._compute_kernel(X)
#     535 if self._sparse:
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/sklearn/svm/_base.py:640, in BaseLibSVM._validate_for_predict(self, X)
#     633         raise ValueError(
#     634             "X.shape[1] = %d should be equal to %d, "
#     635             "the number of samples at training time"
#     636             % (X.shape[1], self.shape_fit_[0])
#     637         )
#     638 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     639 # Check that _n_support is consistent with support_vectors
# --> 640 sv = self.support_vectors_
#     641 if not self._sparse and sv.size > 0 and self.n_support_.sum() != sv.shape[0]:
#     642     raise ValueError(
#     643         f"The internal representation of {self.__class__.__name__} was altered"
#     644     )
#
# AttributeError: 'SVC' object has no attribute 'support_vectors_'
